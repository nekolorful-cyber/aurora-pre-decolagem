# %%
temperatura_interna = 24
temperatura_externa = -12
integridade_estrutural = 1
energia = 82
pressao_tanque = 4.8
modulos_criticos = True

if not (15 <= temperatura_interna <= 30):
    status = "DECOLAGEM ABORTADA"
elif not (-50 <= temperatura_externa <= 40):
    status = "DECOLAGEM ABORTADA"
elif integridade_estrutural != 1:
    status = "DECOLAGEM ABORTADA"
elif energia < 70:
    status = "DECOLAGEM ABORTADA"
elif not (4.5 <= pressao_tanque <= 5.5):
    status = "DECOLAGEM ABORTADA"
elif not modulos_criticos:
    status = "DECOLAGEM ABORTADA"
else:
    status = "PRONTO PARA DECOLAR"

print("Status da Missão:", status)
# Out:
# Status da Missão: PRONTO PARA DECOLAR
